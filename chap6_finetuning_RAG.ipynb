# %% [markdown]
# <a href="https://colab.research.google.com/github/shown5/Hands-on-Generative-AI/blob/main/chap6_finetuning_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# RAG を使ったワークロードを構築してみる

# %%
# 参考メソッド構成

def embeded_documents(documents: List[str]):
  #Use a sentence transformer model to encode the documents

  #Store the documents somewhere

def retrieve_documents(query: str):
  #Use the stored documents to retrieve
  #the most similar documents to the query

def generate_responce(query: str, documents: List[str]):
  #Use the LLM to generate a response

def pipeline(query: str):
  documents = retrieve_documents(query)
  response = generate_response(query, documents)
  return response
